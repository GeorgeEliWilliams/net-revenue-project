# %% [markdown]
# Step 1: Create a DataFrame from the list of dictionaries below:
#
# [{'product_id':23, 'name':'computer', 'wholesale_price': 500, 'retail_price':1000, 'sales':100},
# {'product_id':96, 'name':'Python Workout', 'wholesale_price': 35,'retail_price':75, 'sales':1000},
# {'product_id':97, 'name':'Pandas Workout', 'wholesale_price': 35, 'retail_price':75, 'sales':500},
# {'product_id':15, 'name':'banana', 'wholesale_price': 0.5,'retail_price':1, 'sales':200},
# {'product_id':87, 'name':'sandwich', 'wholesale_price': 3,'retail_price':5, 'sales':300}]
#
#
# Step 2:  Calculate the Total Profit for each product using the formula
#
# ```
#
# net_revenue_per_product = (retail_price - wholesale price) * sales
# ```
#
# Step 3: Determine the following
#
# - How much total net revenue you received from all of these sales?
#
# - What product is product retail price more than twice the wholesale price?
#
# - How much did the store make from food vs. computers vs. books?
#
# - Because your store is doing so well, you’re able to negotiate a 30% discount on the wholesale price of goods. Calculate the new net revenue

# %%
import pandas as pd

# %%
products=[{'product_id':23, 'name':'computer', 'wholesale_price': 500, 'retail_price':1000, 'sales':100}, 
{'product_id':96, 'name':'Python Workout', 'wholesale_price': 35,'retail_price':75, 'sales':1000},
{'product_id':97, 'name':'Pandas Workout', 'wholesale_price': 35, 'retail_price':75, 'sales':500},
{'product_id':15, 'name':'banana', 'wholesale_price': 0.5,'retail_price':1, 'sales':200},
{'product_id':87, 'name':'sandwich', 'wholesale_price': 3,'retail_price':5, 'sales':300}]

# %% [markdown]
# ## Step 1
# Create a dataframe

# %%
dataframe= pd.DataFrame(products)

# %%
dataframe.set_index('product_id',inplace=True)

# %%
dataframe
# Out:
#                       name  wholesale_price  retail_price  sales
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300

# %% [markdown]
# ### Step 2:  Calculate the Total Profit for each product using the formula
# net_revenue_per_product = (retail_price - wholesale price) * sales

# %%
#finding net revenue per product
df=dataframe
df['net_revenue_per_product']=(df['retail_price']-df['wholesale_price'])*df['sales']

# %%
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product
# product_id
# 23                          50000.0
# 96                          40000.0
# 97                          20000.0
# 15                            100.0
# 87                            600.0

# %% [markdown]
# # Step 3: Determine the following
# How much total net revenue you received from all of these sales?

# %%
#Total net revenue
total_net_revenue= sum(df['net_revenue_per_product'])
print(total_net_revenue)
# Out:
# 110700.0

# %% [markdown]
# What product is product retail price more than twice the wholesale price?

# %%
condition=(df['wholesale_price']*2)<df['retail_price']
print(condition)
# Out:
# product_id
# 23    False
# 96     True
# 97     True
# 15    False
# 87    False
# dtype: bool

# %%
df[condition]
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
#
#             net_revenue_per_product
# product_id
# 96                          40000.0
# 97                          20000.0

# %% [markdown]
# How much did the store make from food vs. computers vs. books?

# %%
df['Category']=['computers','books','books','food','food']
category=df.groupby(by=['Category']).sum()
category['net_revenue_per_product']
# Out:
# Category
# books        60000.0
# computers    50000.0
# food           700.0
# Name: net_revenue_per_product, dtype: float64

# %% [markdown]
# Because your store is doing so well, you’re able to negotiate a 30% discount on the wholesale price of goods. Calculate the new net revenue

# %%
#new wholesale price less 30%
df['wholesale_less30%']= df['wholesale_price']*0.7

# %%
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product   Category  wholesale_less30%
# product_id
# 23                          50000.0  computers             350.00
# 96                          40000.0      books              24.50
# 97                          20000.0      books              24.50
# 15                            100.0       food               0.35
# 87                            600.0       food               2.10

# %%
df['new_net_revenue_per_product']=(df['retail_price']-df['wholesale_less30%'])*df['sales']
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product   Category  wholesale_less30%  \
# product_id
# 23                          50000.0  computers             350.00
# 96                          40000.0      books              24.50
# 97                          20000.0      books              24.50
# 15                            100.0       food               0.35
# 87                            600.0       food               2.10
#
#             new_net_revenue_per_product
# product_id
# 23                              65000.0
# 96                              50500.0
# 97                              25250.0
# 15                                130.0
# 87                                870.0

# %%
#Net revenue after 15.20,25 percent rate tax
df['wholesale_less_15%tax'] = df['wholesale_less30%']*0.85
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product   Category  wholesale_less30%  \
# product_id
# 23                          50000.0  computers             350.00
# 96                          40000.0      books              24.50
# 97                          20000.0      books              24.50
# 15                            100.0       food               0.35
# 87                            600.0       food               2.10
#
#             new_net_revenue_per_product  wholesale_less_15%tax  \
# product_id
# 23                              65000.0               297.5000
# 96                              50500.0                20.8250
# 97                              25250.0                20.8250
# 15                                130.0                 0.2975
# 87                                870.0                 1.7850
#
#             wholesale_less20%tax  wholesale_less25%tax
# product_id
# 23                        280.00              262.5000
# 96                         19.60               18.3750
# 97                         19.60               18.3750
# 15                          0.28                0.2625
# 87                          1.68                1.5750

# %%
df['wholesale_less20%tax'] = df['wholesale_less30%']*0.80
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product   Category  wholesale_less30%  \
# product_id
# 23                          50000.0  computers             350.00
# 96                          40000.0      books              24.50
# 97                          20000.0      books              24.50
# 15                            100.0       food               0.35
# 87                            600.0       food               2.10
#
#             new_net_revenue_per_product  wholesale_less_15%tax  \
# product_id
# 23                              65000.0                425.000
# 96                              50500.0                 29.750
# 97                              25250.0                 29.750
# 15                                130.0                  0.425
# 87                                870.0                  2.550
#
#             wholesale_less20%tax  wholesale_less25%tax
# product_id
# 23                        280.00              262.5000
# 96                         19.60               18.3750
# 97                         19.60               18.3750
# 15                          0.28                0.2625
# 87                          1.68                1.5750

# %%
df['wholesale_less25%tax'] = df['wholesale_less30%']*0.75
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product   Category  wholesale_less30%  \
# product_id
# 23                          50000.0  computers             350.00
# 96                          40000.0      books              24.50
# 97                          20000.0      books              24.50
# 15                            100.0       food               0.35
# 87                            600.0       food               2.10
#
#             new_net_revenue_per_product  wholesale_less_15%tax  \
# product_id
# 23                              65000.0                425.000
# 96                              50500.0                 29.750
# 97                              25250.0                 29.750
# 15                                130.0                  0.425
# 87                                870.0                  2.550
#
#             wholesale_less20%tax  wholesale_less25%tax
# product_id
# 23                         400.0              262.5000
# 96                          28.0               18.3750
# 97                          28.0               18.3750
# 15                           0.4                0.2625
# 87                           2.4                1.5750

# %%
df['new_net_revenue_per_product_after15%tax']=(df['retail_price']-df['wholesale_less30%'])*df['sales']*0.85
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product   Category  wholesale_less30%  \
# product_id
# 23                          50000.0  computers             350.00
# 96                          40000.0      books              24.50
# 97                          20000.0      books              24.50
# 15                            100.0       food               0.35
# 87                            600.0       food               2.10
#
#             new_net_revenue_per_product  wholesale_less_15%tax  \
# product_id
# 23                              65000.0               297.5000
# 96                              50500.0                20.8250
# 97                              25250.0                20.8250
# 15                                130.0                 0.2975
# 87                                870.0                 1.7850
#
#             wholesale_less20%tax  wholesale_less25%tax  \
# product_id
# 23                        280.00              262.5000
# 96                         19.60               18.3750
# 97                         19.60               18.3750
# 15                          0.28                0.2625
# 87                          1.68                1.5750
#
#             new_net_revenue_per_product_after15%tax
# product_id
# 23                                          55250.0
# 96                                          42925.0
# 97                                          21462.5
# 15                                            110.5
# 87                                            739.5

# %%
df['new_net_revenue_per_product_after20%tax']=(df['retail_price']-df['wholesale_less30%'])*df['sales']*0.80
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product   Category  wholesale_less30%  \
# product_id
# 23                          50000.0  computers             350.00
# 96                          40000.0      books              24.50
# 97                          20000.0      books              24.50
# 15                            100.0       food               0.35
# 87                            600.0       food               2.10
#
#             new_net_revenue_per_product  wholesale_less_15%tax  \
# product_id
# 23                              65000.0               297.5000
# 96                              50500.0                20.8250
# 97                              25250.0                20.8250
# 15                                130.0                 0.2975
# 87                                870.0                 1.7850
#
#             wholesale_less20%tax  wholesale_less25%tax  \
# product_id
# 23                        280.00              262.5000
# 96                         19.60               18.3750
# 97                         19.60               18.3750
# 15                          0.28                0.2625
# 87                          1.68                1.5750
#
#             new_net_revenue_per_product_after15%tax  \
# product_id
# 23                                          55250.0
# 96                                          42925.0
# 97                                          21462.5
# 15                                            110.5
# 87                                            739.5
#
#             new_net_revenue_per_product_after20%tax
# product_id
# 23                                          52000.0
# 96                                          40400.0
# 97                                          20200.0
# 15                                            104.0
# 87                                            696.0

# %%
df['new_net_revenue_per_product_after25%tax']=(df['retail_price']-df['wholesale_less30%'])*df['sales']*0.75
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product   Category  wholesale_less30%  \
# product_id
# 23                          50000.0  computers             350.00
# 96                          40000.0      books              24.50
# 97                          20000.0      books              24.50
# 15                            100.0       food               0.35
# 87                            600.0       food               2.10
#
#             new_net_revenue_per_product  wholesale_less_15%tax  \
# product_id
# 23                              65000.0               297.5000
# 96                              50500.0                20.8250
# 97                              25250.0                20.8250
# 15                                130.0                 0.2975
# 87                                870.0                 1.7850
#
#             wholesale_less20%tax  wholesale_less25%tax  \
# product_id
# 23                        280.00              262.5000
# 96                         19.60               18.3750
# 97                         19.60               18.3750
# 15                          0.28                0.2625
# 87                          1.68                1.5750
#
#             new_net_revenue_per_product_after15%tax  \
# product_id
# 23                                          55250.0
# 96                                          42925.0
# 97                                          21462.5
# 15                                            110.5
# 87                                            739.5
#
#             new_net_revenue_per_product_after20%tax  \
# product_id
# 23                                          52000.0
# 96                                          40400.0
# 97                                          20200.0
# 15                                            104.0
# 87                                            696.0
#
#             new_net_revenue_per_product_after25%tax
# product_id
# 23                                          48750.0
# 96                                          37875.0
# 97                                          18937.5
# 15                                             97.5
# 87                                            652.5

# %%
df['net_revenue_difference_after15%'] = df['new_net_revenue_per_product']-df['new_net_revenue_per_product_after15%tax']
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product   Category  wholesale_less30%  \
# product_id
# 23                          50000.0  computers             350.00
# 96                          40000.0      books              24.50
# 97                          20000.0      books              24.50
# 15                            100.0       food               0.35
# 87                            600.0       food               2.10
#
#             new_net_revenue_per_product  wholesale_less_15%tax  \
# product_id
# 23                              65000.0               297.5000
# 96                              50500.0                20.8250
# 97                              25250.0                20.8250
# 15                                130.0                 0.2975
# 87                                870.0                 1.7850
#
#             wholesale_less20%tax  wholesale_less25%tax  \
# product_id
# 23                        280.00              262.5000
# 96                         19.60               18.3750
# 97                         19.60               18.3750
# 15                          0.28                0.2625
# 87                          1.68                1.5750
#
#             new_net_revenue_per_product_after15%tax  \
# product_id
# 23                                          55250.0
# 96                                          42925.0
# 97                                          21462.5
# 15                                            110.5
# 87                                            739.5
#
#             new_net_revenue_per_product_after20%tax  \
# product_id
# 23                                          52000.0
# 96                                          40400.0
# 97                                          20200.0
# 15                                            104.0
# 87                                            696.0
#
#             new_net_revenue_per_product_after25%tax  \
# product_id
# 23                                          48750.0
# 96                                          37875.0
# 97                                          18937.5
# 15                                             97.5
# 87                                            652.5
#
#             net_revenue_difference_after15%
# product_id
# 23                                   9750.0
# 96                                   7575.0
# 97                                   3787.5
# 15                                     19.5
# 87                                    130.5

# %%
df['net_revenue_difference_after20%'] = df['new_net_revenue_per_product']-df['new_net_revenue_per_product_after20%tax']
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product   Category  wholesale_less30%  \
# product_id
# 23                          50000.0  computers             350.00
# 96                          40000.0      books              24.50
# 97                          20000.0      books              24.50
# 15                            100.0       food               0.35
# 87                            600.0       food               2.10
#
#             new_net_revenue_per_product  wholesale_less_15%tax  \
# product_id
# 23                              65000.0               297.5000
# 96                              50500.0                20.8250
# 97                              25250.0                20.8250
# 15                                130.0                 0.2975
# 87                                870.0                 1.7850
#
#             wholesale_less20%tax  wholesale_less25%tax  \
# product_id
# 23                        280.00              262.5000
# 96                         19.60               18.3750
# 97                         19.60               18.3750
# 15                          0.28                0.2625
# 87                          1.68                1.5750
#
#             new_net_revenue_per_product_after15%tax  \
# product_id
# 23                                          55250.0
# 96                                          42925.0
# 97                                          21462.5
# 15                                            110.5
# 87                                            739.5
#
#             new_net_revenue_per_product_after20%tax  \
# product_id
# 23                                          52000.0
# 96                                          40400.0
# 97                                          20200.0
# 15                                            104.0
# 87                                            696.0
#
#             new_net_revenue_per_product_after25%tax  \
# product_id
# 23                                          48750.0
# 96                                          37875.0
# 97                                          18937.5
# 15                                             97.5
# 87                                            652.5
#
#             net_revenue_difference_after15%  net_revenue_difference_after20%
# product_id
# 23                                   9750.0                          13000.0
# 96                                   7575.0                          10100.0
# 97                                   3787.5                           5050.0
# 15                                     19.5                             26.0
# 87                                    130.5                            174.0

# %%
df['net_revenue_difference_after25%'] = df['new_net_revenue_per_product']-df['new_net_revenue_per_product_after25%tax']
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product   Category  wholesale_less30%  \
# product_id
# 23                          50000.0  computers             350.00
# 96                          40000.0      books              24.50
# 97                          20000.0      books              24.50
# 15                            100.0       food               0.35
# 87                            600.0       food               2.10
#
#             new_net_revenue_per_product  wholesale_less_15%tax  \
# product_id
# 23                              65000.0               297.5000
# 96                              50500.0                20.8250
# 97                              25250.0                20.8250
# 15                                130.0                 0.2975
# 87                                870.0                 1.7850
#
#             wholesale_less20%tax  wholesale_less25%tax  \
# product_id
# 23                        280.00              262.5000
# 96                         19.60               18.3750
# 97                         19.60               18.3750
# 15                          0.28                0.2625
# 87                          1.68                1.5750
#
#             new_net_revenue_per_product_after15%tax  \
# product_id
# 23                                          55250.0
# 96                                          42925.0
# 97                                          21462.5
# 15                                            110.5
# 87                                            739.5
#
#             new_net_revenue_per_product_after20%tax  \
# product_id
# 23                                          52000.0
# 96                                          40400.0
# 97                                          20200.0
# 15                                            104.0
# 87                                            696.0
#
#             new_net_revenue_per_product_after25%tax  \
# product_id
# 23                                          48750.0
# 96                                          37875.0
# 97                                          18937.5
# 15                                             97.5
# 87                                            652.5
#
#             net_revenue_difference_after15%  net_revenue_difference_after20%  \
# product_id
# 23                                   9750.0                          13000.0
# 96                                   7575.0                          10100.0
# 97                                   3787.5                           5050.0
# 15                                     19.5                             26.0
# 87                                    130.5                            174.0
#
#             net_revenue_difference_after25%
# product_id
# 23                                  16250.0
# 96                                  12625.0
# 97                                   6312.5
# 15                                     32.5
# 87                                    217.5

# %%
df.drop(['wholesale_less_15%tax','wholesale_less20%tax','wholesale_less25%tax'],axis=1,inplace=True)
df
# Out:
#                       name  wholesale_price  retail_price  sales  \
# product_id
# 23                computer            500.0          1000    100
# 96          Python Workout             35.0            75   1000
# 97          Pandas Workout             35.0            75    500
# 15                  banana              0.5             1    200
# 87                sandwich              3.0             5    300
#
#             net_revenue_per_product   Category  wholesale_less30%  \
# product_id
# 23                          50000.0  computers             350.00
# 96                          40000.0      books              24.50
# 97                          20000.0      books              24.50
# 15                            100.0       food               0.35
# 87                            600.0       food               2.10
#
#             new_net_revenue_per_product  \
# product_id
# 23                              65000.0
# 96                              50500.0
# 97                              25250.0
# 15                                130.0
# 87                                870.0
#
#             new_net_revenue_per_product_after15%tax  \
# product_id
# 23                                          55250.0
# 96                                          42925.0
# 97                                          21462.5
# 15                                            110.5
# 87                                            739.5
#
#             new_net_revenue_per_product_after20%tax  \
# product_id
# 23                                          52000.0
# 96                                          40400.0
# 97                                          20200.0
# 15                                            104.0
# 87                                            696.0
#
#             new_net_revenue_per_product_after25%tax  \
# product_id
# 23                                          48750.0
# 96                                          37875.0
# 97                                          18937.5
# 15                                             97.5
# 87                                            652.5
#
#             net_revenue_difference_after15%  net_revenue_difference_after20%  \
# product_id
# 23                                   9750.0                          13000.0
# 96                                   7575.0                          10100.0
# 97                                   3787.5                           5050.0
# 15                                     19.5                             26.0
# 87                                    130.5                            174.0
#
#             net_revenue_difference_after25%
# product_id
# 23                                  16250.0
# 96                                  12625.0
# 97                                   6312.5
# 15                                     32.5
# 87                                    217.5
